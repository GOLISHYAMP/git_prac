# %%
import numpy as np
from PIL import Image
from IPython.display import display

# %%
img = np.random.randint(0,256,(200,200))

# %%
img.shape
# Out:
# (200, 200)

# %%
img = 
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=I size=200x200>

# %%
import re

# %%
str = "Shyam is a good boy"
# search()   and match()
if re.search("is",str):
    print("found")
else:
    print("Not found")
# Out:
# found

# %%
text = "Any works diligently. Any gets good grades. Our student Any is successfull"
re.split("Any",text)
# Out:
# ['',
#  ' works diligently. ',
#  ' gets good grades. Our student ',
#  ' is successfull']

# %%
len(re.findall("Any",text))
# Out:
# 3

# %%
re.search("^Any",text)
# Out:
# <re.Match object; span=(0, 3), match='Any'>

# %%
if re.search("^isy",text):
    print("found")
else:
    print("Not found")
# Out:
# Not found

# %%
li = "ABCBAABCABAABCBA"
re.findall("A",li)
# Out:
# ['A', 'A', 'A', 'A', 'A', 'A', 'A']

# %%
re.findall("[AB]",li)
# Out:
# ['A', 'B', 'B', 'A', 'A', 'B', 'A', 'B', 'A', 'A', 'B', 'B', 'A']

# %%
li = 'ABCBAABCABAABCBAC'

# %%
re.findall("[A][B-C]",li)
# Out:
# ['AB', 'AB', 'AB', 'AB', 'AC']

# %%
re.findall("AB|AC",li)  # | is a pipe or OR operator
# Out:
# ['AB', 'AB', 'AB', 'AB', 'AC']

# %%
text
# Out:
# 'Any works diligently. Any gets good grades. Our student Any is successfull'

# %%
re.findall("Any|is",text)
# Out:
# ['Any', 'Any', 'Any', 'is']

# %%
re.findall("[^A]",li)
# Out:
# ['B', 'C', 'B', 'B', 'C', 'B', 'B', 'C', 'B', 'C']

# %% [markdown]
# ### Remember here ^ is used previously to check whether the sent starts with word but its function changes when deals with set []

# %%
li
# Out:
# 'ABCBAABCABAABCBAC'

# %%
re.findall("^A",li)
# Out:
# ['A']

# %%
re.findall("A{2,10}",li)
# Out:
# ['AA', 'AA']

# %%
re.findall("AA",li)
# Out:
# ['AA', 'AA']

# %%
re.findall("A{1,1}A{1,1}",li)
# Out:
# ['AA', 'AA']

# %%
re.findall("A{2,2}",li)
# Out:
# ['AA', 'AA']

# %%
re.findall("A{2}",li)
# Out:
# ['AA', 'AA']

# %%
li
# Out:
# 'ABCBAABCABAABCBAC'

# %%
re.findall("A{1,10}B{1,10}C{1,10}",li)
# Out:
# ['ABC', 'AABC', 'AABC']

# %%
import numpy as np

# %%
arr = np.array([[1,2],[3,4]])

# %%
arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.random.rand(4)
# Out:
# array([0.11024065, 0.63457167, 0.81602132, 0.0956462 ])

# %%
np.random.rand(4,1)
# Out:
# array([[0.54981123],
#        [0.73371548],
#        [0.94929128],
#        [0.51612012]])

# %%
st = "'I refer to https://google.com and I never refer http://www.baidu.com if I have to search anything'"
re.findall("(?<=[https]:\/\/)(\w.)*",st)
# Out:
# ['le', 'if']

# %%
import re
s = 'ACAABAACAAAB'
result = re.findall('A{1,2}', s)
L = len(result)

# %%
np.random.rand(4)
# Out:
# array([0.34881682, 0.76825535, 0.01876413, 0.15911759])

# %%
np.arange(1,4,1)
# Out:
# array([1, 2, 3])

# %%
li = [100,200,300,1,2,3,1,20,30,1000,2000,3000]
#for i,temp in enumerate(li):
 #   print(i,temp)
n = 3
points = [li[i:i+n] for i in range(0,len(li),n)]
print(points)
# Out:
# [[100, 200, 300], [1, 2, 3], [1, 20, 30], [1000, 2000, 3000]]

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello sai")
# Out:
# Hello sai

# %%
print("putting prac.ipynb in .gitignore file")
# Out:
# putting prac.ipynb in .gitignore file
