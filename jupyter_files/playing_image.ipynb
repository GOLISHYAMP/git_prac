# %%
import numpy as np
from PIL import Image
from IPython.display import display

# %%
im = Image.open("C:\\Users\\SPURUSHO\\Downloads\\Black-and-White-Wallpaper-1.webp")

# %%
display(im)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=954x600>

# %%
image_arr = np.array(im)
image_arr.shape
# Out:
# (600, 954, 3)

# %%
mask = np.full((600,954,3),255)
mask.shape
# Out:
# (600, 954, 3)

# %%
modified_img = image_arr - mask
modified_img = modified_img * -1
modified_img = modified_img.astype(np.uint8)
display(Image.fromarray(modified_img))
# Out:
# <PIL.Image.Image image mode=RGB size=954x600>
